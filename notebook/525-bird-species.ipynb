# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## Data manipulation

# %%
import pathlib

data_dir = pathlib.Path("./data/")

training_image_count = len(list(data_dir.glob('train/*/*.jpg')))
test_image_count = len(list(data_dir.glob('test/*/*.jpg')))
validation_image_count = len(list(data_dir.glob('valid/*/*.jpg')))
total_count = training_image_count + test_image_count + validation_image_count

print(f"training_image_count: {training_image_count}")
print(f"test_image_count: {test_image_count}")
print(f"validation_image_count: {validation_image_count}")
print(f"total_count: {total_count}")
# Out:
# training_image_count: 84635
# test_image_count: 2625
# validation_image_count: 2625
# total_count: 89885

# %% [markdown]
# #### Random pictures from dataset

# %%
from random import randrange

image_1 = PIL.Image.open(str(list(data_dir.glob('*/*/*.jpg'))[randrange(total_count)]))
image_2 = PIL.Image.open(str(list(data_dir.glob('*/*/*.jpg'))[randrange(total_count)]))
image_3 = PIL.Image.open(str(list(data_dir.glob('*/*/*.jpg'))[randrange(total_count)]))
image_4 = PIL.Image.open(str(list(data_dir.glob('*/*/*.jpg'))[randrange(total_count)]))

from matplotlib import pyplot as plt

fig = plt.figure(figsize=(10, 7)) 
rows = 2
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(image_1) 
plt.axis('off') 
plt.title(image_1.filename.split("/")[2]) 

fig.add_subplot(rows, columns, 2) 
plt.imshow(image_2) 
plt.axis('off') 
plt.title(image_2.filename.split("/")[2]) 

fig.add_subplot(rows, columns, 3) 
plt.imshow(image_3) 
plt.axis('off') 
plt.title(image_3.filename.split("/")[2]) 

fig.add_subplot(rows, columns, 4) 
plt.imshow(image_4) 
plt.axis('off') 
plt.title(image_4.filename.split("/")[2])
# Out:
# Text(0.5, 1.0, 'HARPY EAGLE')
